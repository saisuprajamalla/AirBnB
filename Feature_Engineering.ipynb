# %%
import re
import pandas as pd
import numpy as np
from sklearn.base import TransformerMixin

data_features = pd.read_csv('data/airbnb_features_selection.csv')

# %% [markdown]
# # Impute NaN values with mean values

# %% [markdown]
# Impute host_neighbourhood NaN values with either of corresponding city values or neighbourhood values or default value 'New York'

# %%
class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

xt = DataFrameImputer().fit_transform(data_features)

xt.to_csv('data/dummy.csv', index=False)

# %%
data_features = pd.read_csv('data/dummy.csv')
data_features
# Out:
#         host_neighbourhood host_identity_verified        neighbourhood  \
# 0                   Harlem                      t               Harlem
# 1                Gravesend                      t           Kensington
# 2                  Midtown                      t              Midtown
# 3        East Williamsburg                      t         Williamsburg
# 4                   Harlem                      t               Harlem
# 5             Clinton Hill                      t         Clinton Hill
# 6           Hell's Kitchen                      t       Hell's Kitchen
# 7             Times Square                      f       Hell's Kitchen
# 8       Bedford-Stuyvesant                      f   Bedford-Stuyvesant
# 9        Greenwood Heights                      f    Greenwood Heights
# 10             Murray Hill                      t          Murray Hill
# 11          Hell's Kitchen                      f       Hell's Kitchen
# 12         Upper West Side                      t      Upper West Side
# 13         Lower East Side                      t      Lower East Side
# 14         Upper West Side                      t      Upper West Side
# 15         Upper West Side                      f      Upper West Side
# 16            Times Square                      t       Hell's Kitchen
# 17              Park Slope                      t           Park Slope
# 18         Upper West Side                      t      Upper West Side
# 19            West Village                      t         West Village
# 20            Williamsburg                      f         Williamsburg
# 21             East Harlem                      t          East Harlem
# 22             Fort Greene                      t          Fort Greene
# 23            West Village                      t         West Village
# 24                 Chelsea                      t              Chelsea
# 25            Williamsburg                      t         Williamsburg
# 26         Upper West Side                      t      Upper West Side
# 27              Park Slope                      t           Park Slope
# 28              Park Slope                      t           Park Slope
# 29              Park Slope                      t           Park Slope
# ...                    ...                    ...                  ...
# 48822     Hamilton Heights                      f     Hamilton Heights
# 48823     Hamilton Heights                      f     Hamilton Heights
# 48824     Roosevelt Island                      t     Roosevelt Island
# 48825              Chelsea                      f              Chelsea
# 48826           Greenpoint                      t           Greenpoint
# 48827  Morningside Heights                      t  Morningside Heights
# 48828               Harlem                      f               Harlem
# 48829  Morningside Heights                      f  Morningside Heights
# 48830          East Harlem                      t          East Harlem
# 48831         Williamsburg                      f         Williamsburg
# 48832   Bedford-Stuyvesant                      t   Bedford-Stuyvesant
# 48833         Williamsburg                      t         Williamsburg
# 48834             Flatbush                      f             Flatbush
# 48835                 Soho                      f                 Soho
# 48836   Bedford-Stuyvesant                      t   Bedford-Stuyvesant
# 48837         Point Breeze                      f          Fort Greene
# 48838         Williamsburg                      f             Bushwick
# 48839         Williamsburg                      f              Midwood
# 48840      Upper East Side                      f      Upper East Side
# 48841       Hell's Kitchen                      f       Hell's Kitchen
# 48842             Flushing                      f             Flushing
# 48843          Bensonhurst                      f          Bensonhurst
# 48844              Astoria                      f              Astoria
# 48845      Upper West Side                      t      Upper West Side
# 48846        Crown Heights                      t        Crown Heights
# 48847          Throgs Neck                      f          Throgs Neck
# 48848         Williamsburg                      f          Bensonhurst
# 48849         Williamsburg                      f             New Dorp
# 48850   Financial District                      t   Financial District
# 48851     Hamilton Heights                      f     Hamilton Heights
#
#                  city  zipcode property_type        room_type  accommodates  \
# 0            New York    10026     Apartment     Private room             2
# 1           Brooklyn     11218     Apartment     Private room             4
# 2            New York    10018     Apartment  Entire home/apt             2
# 3            Brooklyn    11206     Apartment     Private room             2
# 4            New York    10027     Apartment     Private room             2
# 5            Brooklyn    11238         Other  Entire home/apt             3
# 6            New York    10036     Apartment  Entire home/apt             3
# 7            New York    10019     Apartment  Entire home/apt             2
# 8            Brooklyn    11216     Apartment     Private room             2
# 9            Brooklyn    11232     Apartment  Entire home/apt             4
# 10           New York    10016     Apartment  Entire home/apt             2
# 11           New York    10019     Apartment     Private room             2
# 12           New York    10025     Apartment     Private room             1
# 13           New York    10002     Apartment  Entire home/apt             3
# 14           New York    10025     Apartment  Entire home/apt             2
# 15           New York    10025     Apartment  Entire home/apt             2
# 16           New York    10036     Apartment     Private room             2
# 17           Brooklyn    11215         House     Private room             2
# 18           New York    10024     Apartment     Private room             2
# 19           New York    10014     Apartment  Entire home/apt             1
# 20           Brooklyn    11211     Apartment  Entire home/apt             3
# 21           New York    10029     Apartment     Private room             1
# 22           Brooklyn    11205         House  Entire home/apt             4
# 23           New York    10014     Apartment  Entire home/apt             2
# 24           New York    10011     Apartment     Private room             3
# 25           Brooklyn    11211          Loft  Entire home/apt             4
# 26           New York    10024     Apartment  Entire home/apt             4
# 27           Brooklyn    11217     Townhouse     Private room             4
# 28           Brooklyn    11217         House     Private room             2
# 29           Brooklyn    11217         House     Private room             3
# ...               ...      ...           ...              ...           ...
# 48822        New York  10031.0     Apartment  Entire home/apt             7
# 48823        New York  10030.0     Apartment     Private room             2
# 48824        New York  10044.0     Apartment  Entire home/apt             6
# 48825        New York  10011.0     Apartment  Entire home/apt             2
# 48826        Brooklyn  11222.0     Apartment  Entire home/apt             3
# 48827        New York  10027.0     Apartment     Private room             2
# 48828        New York  10037.0     Apartment  Entire home/apt             3
# 48829        New York  10025.0     Apartment  Entire home/apt             3
# 48830        New York  10029.0     Apartment     Private room             1
# 48831        Brooklyn  11211.0     Apartment     Private room             2
# 48832        Brooklyn  11233.0     Townhouse  Entire home/apt             2
# 48833        Brooklyn  11249.0     Apartment  Entire home/apt             2
# 48834        Brooklyn  11226.0     Apartment     Private room             2
# 48835        New York  10013.0     Apartment  Entire home/apt             4
# 48836        Brooklyn  11216.0     Apartment  Entire home/apt             2
# 48837        Brooklyn  11217.0          Loft  Entire home/apt             4
# 48838       Brooklyn   11221.0     Apartment     Private room             2
# 48839       Brooklyn   11230.0     Apartment     Private room             3
# 48840        New York  10075.0     Apartment  Entire home/apt             2
# 48841        New York  10019.0     Apartment  Entire home/apt             3
# 48842       Flushing   11355.0     Apartment  Entire home/apt             4
# 48843        Brooklyn  11214.0         Other  Entire home/apt             1
# 48844          Queens  11102.0     Apartment     Private room             2
# 48845        New York  10025.0     Apartment  Entire home/apt             5
# 48846        Brooklyn  11216.0     Apartment  Entire home/apt             2
# 48847           Bronx  10465.0         House  Entire home/apt             6
# 48848        Brooklyn  11204.0   Condominium     Private room             2
# 48849  Staten Island   10306.0     Apartment  Entire home/apt             3
# 48850        New York  10038.0     Apartment  Entire home/apt             4
# 48851        New York  10031.0     Apartment     Private room             1
#
#        bathrooms  bedrooms         ...           availability_365  \
# 0       1.000000  1.000000         ...                        316
# 1       1.000000  2.000000         ...                        365
# 2       1.000000  0.000000         ...                        365
# 3       1.000000  1.000000         ...                        279
# 4       1.000000  1.000000         ...                        365
# 5       1.000000  1.000000         ...                        126
# 6       1.000000  1.000000         ...                         17
# 7       1.000000  1.000000         ...                          2
# 8       1.132942  1.000000         ...                        365
# 9       1.500000  3.000000         ...                        358
# 10      1.000000  1.000000         ...                          0
# 11      1.000000  1.000000         ...                        171
# 12      1.000000  1.000000         ...                          0
# 13      1.000000  1.000000         ...                        181
# 14      1.000000  1.000000         ...                        249
# 15      1.000000  1.000000         ...                        365
# 16      1.000000  1.000000         ...                         49
# 17      1.132942  1.000000         ...                        279
# 18      1.000000  1.000000         ...                         80
# 19      1.000000  1.000000         ...                          1
# 20      1.000000  1.153332         ...                        281
# 21      1.000000  1.000000         ...                          0
# 22      1.000000  1.000000         ...                        353
# 23      1.132942  1.153332         ...                        125
# 24      1.000000  1.000000         ...                          0
# 25      1.000000  1.153332         ...                         87
# 26      1.000000  1.000000         ...                        195
# 27      3.000000  1.000000         ...                        330
# 28      1.000000  1.000000         ...                        303
# 29      1.000000  1.000000         ...                        307
# ...          ...       ...         ...                        ...
# 48822   1.000000  4.000000         ...                        154
# 48823   1.000000  4.000000         ...                         21
# 48824   1.500000  2.000000         ...                        359
# 48825   1.000000  0.000000         ...                        281
# 48826   1.000000  0.000000         ...                         18
# 48827   1.000000  1.000000         ...                         84
# 48828   1.000000  1.000000         ...                        154
# 48829   1.000000  0.000000         ...                          5
# 48830   1.500000  1.000000         ...                         68
# 48831   1.000000  1.000000         ...                         20
# 48832   1.000000  1.000000         ...                         30
# 48833   1.000000  1.000000         ...                          9
# 48834   1.000000  1.000000         ...                        365
# 48835   1.000000  2.000000         ...                          5
# 48836   1.000000  0.000000         ...                         67
# 48837   1.000000  0.000000         ...                         17
# 48838   1.000000  1.000000         ...                         83
# 48839   1.000000  1.000000         ...                         87
# 48840   1.000000  1.000000         ...                         19
# 48841   1.000000  0.000000         ...                          1
# 48842   1.000000  2.000000         ...                         74
# 48843   1.000000  0.000000         ...                         18
# 48844   1.000000  1.000000         ...                        365
# 48845   1.000000  3.000000         ...                         13
# 48846   1.000000  1.000000         ...                         30
# 48847   1.000000  0.000000         ...                         35
# 48848   1.000000  1.000000         ...                         62
# 48849   1.000000  0.000000         ...                          0
# 48850   1.000000  2.000000         ...                          1
# 48851   2.000000  1.000000         ...                         30
#
#       number_of_reviews  review_scores_rating review_scores_accuracy  \
# 0                   164             92.000000               9.000000
# 1                     7             97.000000              10.000000
# 2                    29             97.000000               9.000000
# 3                    27             97.000000              10.000000
# 4                     0             93.559763               9.575481
# 5                   181             90.000000               9.000000
# 6                    26             88.000000               9.000000
# 7                    58             93.000000               9.000000
# 8                    51             90.000000               8.000000
# 9                     1             97.000000              10.000000
# 10                   64             93.000000               9.000000
# 11                  371             84.000000               8.000000
# 12                  118             98.000000              10.000000
# 13                  146             93.000000               9.000000
# 14                   37             94.000000              10.000000
# 15                   25             91.000000              10.000000
# 16                  143             97.000000               9.000000
# 17                  148             93.000000               9.000000
# 18                   66             92.000000               9.000000
# 19                   24             96.000000              10.000000
# 20                   86             90.000000               9.000000
# 21                  225             97.000000              10.000000
# 22                  144             96.000000              10.000000
# 23                   61             92.000000              10.000000
# 24                  209             96.000000               9.000000
# 25                   10             98.000000               9.000000
# 26                   14             95.000000               9.000000
# 27                  103             93.000000               9.000000
# 28                   26             94.000000               9.000000
# 29                   51             90.000000               9.000000
# ...                 ...                   ...                    ...
# 48822                 0             93.559763               9.575481
# 48823                 0             93.559763               9.575481
# 48824                 0             93.559763               9.575481
# 48825                 0             93.559763               9.575481
# 48826                 0             93.559763               9.575481
# 48827                 0             93.559763               9.575481
# 48828                 0             93.559763               9.575481
# 48829                 0             93.559763               9.575481
# 48830                 0             93.559763               9.575481
# 48831                 0             93.559763               9.575481
# 48832                 0             93.559763               9.575481
# 48833                 0             93.559763               9.575481
# 48834                 0             93.559763               9.575481
# 48835                 0             93.559763               9.575481
# 48836                 0             93.559763               9.575481
# 48837                 0             93.559763               9.575481
# 48838                 0             93.559763               9.575481
# 48839                 0             93.559763               9.575481
# 48840                 0             93.559763               9.575481
# 48841                 0             93.559763               9.575481
# 48842                 0             93.559763               9.575481
# 48843                 0             93.559763               9.575481
# 48844                 0             93.559763               9.575481
# 48845                 0             93.559763               9.575481
# 48846                 0             93.559763               9.575481
# 48847                 0             93.559763               9.575481
# 48848                 0             93.559763               9.575481
# 48849                 0             93.559763               9.575481
# 48850                 0             93.559763               9.575481
# 48851                 0             93.559763               9.575481
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                      9.000000               10.00000
# 1                     10.000000               10.00000
# 2                      9.000000                9.00000
# 3                     10.000000               10.00000
# 4                      9.242865                9.72651
# 5                      9.000000               10.00000
# 6                      9.000000               10.00000
# 7                      8.000000               10.00000
# 8                      8.000000               10.00000
# 9                     10.000000               10.00000
# 10                     9.000000                9.00000
# 11                     7.000000                9.00000
# 12                    10.000000               10.00000
# 13                     9.000000               10.00000
# 14                     9.000000               10.00000
# 15                     8.000000               10.00000
# 16                     9.000000               10.00000
# 17                     9.000000               10.00000
# 18                     9.000000               10.00000
# 19                     9.000000                9.00000
# 20                    10.000000               10.00000
# 21                    10.000000               10.00000
# 22                    10.000000               10.00000
# 23                     8.000000               10.00000
# 24                    10.000000               10.00000
# 25                     9.000000               10.00000
# 26                     9.000000               10.00000
# 27                     9.000000                9.00000
# 28                     9.000000               10.00000
# 29                     9.000000                9.00000
# ...                         ...                    ...
# 48822                  9.242865                9.72651
# 48823                  9.242865                9.72651
# 48824                  9.242865                9.72651
# 48825                  9.242865                9.72651
# 48826                  9.242865                9.72651
# 48827                  9.242865                9.72651
# 48828                  9.242865                9.72651
# 48829                  9.242865                9.72651
# 48830                  9.242865                9.72651
# 48831                  9.242865                9.72651
# 48832                  9.242865                9.72651
# 48833                  9.242865                9.72651
# 48834                  9.242865                9.72651
# 48835                  9.242865                9.72651
# 48836                  9.242865                9.72651
# 48837                  9.242865                9.72651
# 48838                  9.242865                9.72651
# 48839                  9.242865                9.72651
# 48840                  9.242865                9.72651
# 48841                  9.242865                9.72651
# 48842                  9.242865                9.72651
# 48843                  9.242865                9.72651
# 48844                  9.242865                9.72651
# 48845                  9.242865                9.72651
# 48846                  9.242865                9.72651
# 48847                  9.242865                9.72651
# 48848                  9.242865                9.72651
# 48849                  9.242865                9.72651
# 48850                  9.242865                9.72651
# 48851                  9.242865                9.72651
#
#       review_scores_communication  review_scores_location  \
# 0                        9.000000                  9.0000
# 1                       10.000000                 10.0000
# 2                       10.000000                 10.0000
# 3                       10.000000                 10.0000
# 4                        9.744402                  9.4733
# 5                       10.000000                  9.0000
# 6                       10.000000                 10.0000
# 7                       10.000000                 10.0000
# 8                       10.000000                  9.0000
# 9                       10.000000                  8.0000
# 10                      10.000000                 10.0000
# 11                       9.000000                 10.0000
# 12                      10.000000                 10.0000
# 13                      10.000000                  9.0000
# 14                      10.000000                  9.0000
# 15                      10.000000                 10.0000
# 16                      10.000000                 10.0000
# 17                      10.000000                 10.0000
# 18                      10.000000                 10.0000
# 19                      10.000000                 10.0000
# 20                      10.000000                  9.0000
# 21                      10.000000                 10.0000
# 22                      10.000000                 10.0000
# 23                      10.000000                 10.0000
# 24                      10.000000                 10.0000
# 25                       9.000000                 10.0000
# 26                      10.000000                 10.0000
# 27                      10.000000                 10.0000
# 28                       9.000000                 10.0000
# 29                       9.000000                 10.0000
# ...                           ...                     ...
# 48822                    9.744402                  9.4733
# 48823                    9.744402                  9.4733
# 48824                    9.744402                  9.4733
# 48825                    9.744402                  9.4733
# 48826                    9.744402                  9.4733
# 48827                    9.744402                  9.4733
# 48828                    9.744402                  9.4733
# 48829                    9.744402                  9.4733
# 48830                    9.744402                  9.4733
# 48831                    9.744402                  9.4733
# 48832                    9.744402                  9.4733
# 48833                    9.744402                  9.4733
# 48834                    9.744402                  9.4733
# 48835                    9.744402                  9.4733
# 48836                    9.744402                  9.4733
# 48837                    9.744402                  9.4733
# 48838                    9.744402                  9.4733
# 48839                    9.744402                  9.4733
# 48840                    9.744402                  9.4733
# 48841                    9.744402                  9.4733
# 48842                    9.744402                  9.4733
# 48843                    9.744402                  9.4733
# 48844                    9.744402                  9.4733
# 48845                    9.744402                  9.4733
# 48846                    9.744402                  9.4733
# 48847                    9.744402                  9.4733
# 48848                    9.744402                  9.4733
# 48849                    9.744402                  9.4733
# 48850                    9.744402                  9.4733
# 48851                    9.744402                  9.4733
#
#        review_scores_value  cancellation_policy
# 0                 9.000000               strict
# 1                10.000000             moderate
# 2                 9.000000               strict
# 3                10.000000               strict
# 4                 9.395225               strict
# 5                 9.000000             moderate
# 6                 9.000000               strict
# 7                 9.000000               strict
# 8                 9.000000               strict
# 9                10.000000               strict
# 10               10.000000               strict
# 11                9.000000               strict
# 12               10.000000             flexible
# 13                9.000000               strict
# 14                9.000000               strict
# 15                9.000000               strict
# 16               10.000000             moderate
# 17                9.000000               strict
# 18                9.000000             moderate
# 19                9.000000               strict
# 20                9.000000               strict
# 21               10.000000             moderate
# 22               10.000000             moderate
# 23                9.000000               strict
# 24                9.000000               strict
# 25               10.000000               strict
# 26                9.000000             moderate
# 27                9.000000             moderate
# 28                9.000000             moderate
# 29                9.000000             flexible
# ...                    ...                  ...
# 48822             9.395225             flexible
# 48823             9.395225             flexible
# 48824             9.395225             flexible
# 48825             9.395225             flexible
# 48826             9.395225             flexible
# 48827             9.395225             flexible
# 48828             9.395225             flexible
# 48829             9.395225             flexible
# 48830             9.395225             flexible
# 48831             9.395225             flexible
# 48832             9.395225             flexible
# 48833             9.395225             moderate
# 48834             9.395225             flexible
# 48835             9.395225             flexible
# 48836             9.395225             flexible
# 48837             9.395225             moderate
# 48838             9.395225             flexible
# 48839             9.395225             flexible
# 48840             9.395225               strict
# 48841             9.395225             flexible
# 48842             9.395225             flexible
# 48843             9.395225             flexible
# 48844             9.395225             flexible
# 48845             9.395225             flexible
# 48846             9.395225             flexible
# 48847             9.395225             flexible
# 48848             9.395225             flexible
# 48849             9.395225             flexible
# 48850             9.395225             flexible
# 48851             9.395225             flexible
#
# [48852 rows x 30 columns]

# %% [markdown]
# # Remove dollar sign from Security_Deposit, Cleaning_Fee, Extra_People features and store it as float value

# %%
import re

for i in range(len(data_features['security_deposit'])):
    if i%10000 == 0:
        print "Processed %d rows" %(i)
    security_deposit = data_features['security_deposit'][i]
    security_deposit = re.sub('[,$]', '', security_deposit)
    data_features['security_deposit'][i] = float(security_deposit)
    
    cleaning_fee = data_features['cleaning_fee'][i]
    cleaning_fee = re.sub('[,$]', '', cleaning_fee)
    data_features['cleaning_fee'][i] = float(cleaning_fee)
    
    extra_people = data_features['extra_people'][i]
    extra_people = re.sub('[,$]', '', extra_people)
    data_features['extra_people'][i] = float(extra_people)
    
data_features.to_csv('data/preprocessed.csv', index=False)
# Out:
# Processed 0 rows
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# Processed 10000 rows
# Processed 20000 rows
# Processed 30000 rows
# Processed 40000 rows
