# %%
# %matplotlib inline
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np
import re
import csv

# %%
raw_data = pd.read_csv('data/listings.csv')
print "Total %s objects" % raw_data['id'].count()
# Out:
# Total 48852 objects

# %%
print "Total %s objects" % raw_data.count()
# Out:
# Total id                                  48852
# listing_url                         48852
# scrape_id                           48852
# last_scraped                        48852
# name                                48824
# summary                             47464
# space                               33201
# description                         48817
# experiences_offered                 48852
# neighborhood_overview               28841
# notes                               18385
# transit                             30391
# access                              28476
# interaction                         27346
# house_rules                         29259
# thumbnail_url                           0
# medium_url                              0
# picture_url                         48852
# xl_picture_url                          0
# host_id                             48852
# host_url                            48852
# host_name                           48746
# host_since                          48746
# host_location                       48563
# host_about                          29776
# host_response_time                  31322
# host_response_rate                  31322
# host_acceptance_rate                    0
# host_is_superhost                   48746
# host_thumbnail_url                  48746
#                                     ...
# extra_people                        48852
# minimum_nights                      48852
# maximum_nights                      48852
# calendar_updated                    48852
# has_availability                    48852
# availability_30                     48852
# availability_60                     48852
# availability_90                     48852
# availability_365                    48852
# calendar_last_scraped               48852
# number_of_reviews                   48852
# first_review                        37916
# last_review                         37972
# review_scores_rating                36946
# review_scores_accuracy              36870
# review_scores_cleanliness           36893
# review_scores_checkin               36835
# review_scores_communication         36886
# review_scores_location              36816
# review_scores_value                 36817
# requires_license                    48852
# license                                 0
# jurisdiction_names                      6
# instant_bookable                    48852
# is_business_travel_ready            48852
# cancellation_policy                 48852
# require_guest_profile_picture       48852
# require_guest_phone_verification    48852
# calculated_host_listings_count      48852
# reviews_per_month                   37916
# Length: 96, dtype: int64 objects

# %%
# import columns we want to extract
header = ['price',
          'host_neighbourhood',
          'host_identity_verified',
          'neighbourhood',
          'city',
          'zipcode',
          'property_type',
          'room_type',
          'accommodates',
          'bathrooms',
          'bedrooms',
          'beds',
          'bed_type',
          'square_feet',
          'security_deposit',
          'cleaning_fee',
          'guests_included',
          'extra_people',
          'availability_30',
          'availability_60',
          'availability_90',
          'availability_365',
          'number_of_reviews',
          'review_scores_rating',
          'review_scores_accuracy',
          'review_scores_cleanliness',
          'review_scores_checkin',
          'review_scores_communication',
          'review_scores_location',
          'review_scores_value',
          'cancellation_policy']

# %%
raw_data.to_csv('data/airbnb_data_analysis.csv', columns = header, index=False)
data_features = pd.read_csv('data/airbnb_data_analysis.csv')
print "Total %s objects" % data_features.count()
# Out:
# Total price                          48852
# host_neighbourhood             42031
# host_identity_verified         48746
# neighbourhood                  48842
# city                           48791
# zipcode                        48172
# property_type                  48852
# room_type                      48852
# accommodates                   48852
# bathrooms                      48713
# bedrooms                       48796
# beds                           48783
# bed_type                       48852
# square_feet                      533
# security_deposit               28101
# cleaning_fee                   35867
# guests_included                48852
# extra_people                   48852
# availability_30                48852
# availability_60                48852
# availability_90                48852
# availability_365               48852
# number_of_reviews              48852
# review_scores_rating           36946
# review_scores_accuracy         36870
# review_scores_cleanliness      36893
# review_scores_checkin          36835
# review_scores_communication    36886
# review_scores_location         36816
# review_scores_value            36817
# cancellation_policy            48852
# dtype: int64 objects

# %%
data_features['price'].count()
# Out:
# 48852

# %%
# replacing NaN values with 0
data_features.fillna(0, inplace=True)

prices = []

# the values are stored as '$7,000' instead of 7000.
# # data cleaning to make the values into floats
for i in range(len(data_features['price'])):
    price = data_features['price'][i]
    price = re.sub('[,$]', '', price)
    prices.append(float(price))
print prices[0:3] , len(prices)

# # replacing the current column into a new one for future use
data_features['price'] = prices
# Out:
# [59.0, 39.0, 225.0] 48852

# %%
# excluding listings with "0" for price, bedrooms, etc
data_features = data_features[data_features.city != 0]
data_features = data_features[data_features.price > 0]
data_features = data_features[data_features.bedrooms > 0]
data_features = data_features[data_features.beds > 0]
data_features = data_features[data_features.review_scores_rating > 0]
data_features = data_features[data_features.accommodates > 0]
data_features = data_features[data_features.bathrooms > 0]

# first 5 of the listing file
data_features[0:5]
# Out:
#    price host_neighbourhood host_identity_verified   neighbourhood       city  \
# 0   59.0             Harlem                      t          Harlem   New York
# 1   39.0          Gravesend                      t      Kensington  Brooklyn
# 3   70.0  East Williamsburg                      t    Williamsburg   Brooklyn
# 5   89.0       Clinton Hill                      t    Clinton Hill   Brooklyn
# 6  150.0     Hell's Kitchen                      t  Hell's Kitchen   New York
#
#   zipcode property_type        room_type  accommodates  bathrooms  \
# 0   10026     Apartment     Private room             2        1.0
# 1   11218     Apartment     Private room             4        1.0
# 3   11206     Apartment     Private room             2        1.0
# 5   11238         Other  Entire home/apt             3        1.0
# 6   10036     Apartment  Entire home/apt             3        1.0
#
#           ...           availability_365  number_of_reviews  \
# 0         ...                        316                164
# 1         ...                        365                  7
# 3         ...                        279                 27
# 5         ...                        126                181
# 6         ...                         17                 26
#
#   review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 0                 92.0                     9.0                       9.0
# 1                 97.0                    10.0                      10.0
# 3                 97.0                    10.0                      10.0
# 5                 90.0                     9.0                       9.0
# 6                 88.0                     9.0                       9.0
#
#   review_scores_checkin  review_scores_communication review_scores_location  \
# 0                  10.0                          9.0                    9.0
# 1                  10.0                         10.0                   10.0
# 3                  10.0                         10.0                   10.0
# 5                  10.0                         10.0                    9.0
# 6                  10.0                         10.0                   10.0
#
#    review_scores_value  cancellation_policy
# 0                  9.0               strict
# 1                 10.0             moderate
# 3                 10.0               strict
# 5                  9.0             moderate
# 6                  9.0               strict
#
# [5 rows x 31 columns]

# %% [markdown]
# # Property type distribution

# %%
# using Counter to analyze frequency of each property type
nh = Counter(data_features['property_type'])
nh
# Out:
# Counter({'Aparthotel': 4,
#          'Apartment': 27502,
#          'Bed and breakfast': 87,
#          'Boat': 3,
#          'Boutique hotel': 29,
#          'Bungalow': 16,
#          'Cabin': 1,
#          'Camper/RV': 2,
#          'Casa particular (Cuba)': 1,
#          'Castle': 1,
#          'Cave': 2,
#          'Chalet': 1,
#          'Condominium': 400,
#          'Cottage': 1,
#          'Dorm': 17,
#          'Earth house': 3,
#          'Guest suite': 93,
#          'Guesthouse': 35,
#          'Hostel': 19,
#          'Hotel': 6,
#          'House': 2900,
#          'Hut': 2,
#          'In-law': 9,
#          'Island': 1,
#          'Loft': 792,
#          'Other': 157,
#          'Serviced apartment': 113,
#          'Tent': 1,
#          'Timeshare': 19,
#          'Tiny house': 1,
#          'Townhouse': 902,
#          'Treehouse': 1,
#          'Vacation home': 9,
#          'Villa': 14,
#          'Yurt': 1})

# %%
nh_df = pd.DataFrame.from_dict(nh, orient='index').sort_values(by=0)
nh_df.columns = ['property_type']
nh_df.plot.bar(y= 'property_type', 
                 color = 'LightBlue',
                 fontsize = 20,
                 legend = False,
                 figsize= (20, 10),
                 title = "Property type distribution")

# %% [markdown]
# # distribution of room types

# %%
# using Counter to analyze frequency of room types
r = data_features.room_type
nh = Counter(r)
nh
# Out:
# Counter({'Entire home/apt': 15849, 'Private room': 16485, 'Shared room': 811})

# %%
nh_df = pd.DataFrame.from_dict(nh, orient='index').sort_values(by=0)
nh_df.columns =['room_type']

# %%
nh_df.plot.pie(y = 'room_type', 
                 colormap = 'Greens_r', 
                 figsize=(6,6), 
                 fontsize = 18, autopct = '%.2f',
                 legend = False,
                 title = 'Room Type Distribution')

# %% [markdown]
# # Frequency of number of bedrooms

# %%
nh = Counter(data_features['bedrooms'])
nh
# Out:
# Counter({1.0: 26322,
#          2.0: 4860,
#          3.0: 1467,
#          4.0: 374,
#          5.0: 80,
#          6.0: 21,
#          7.0: 13,
#          8.0: 3,
#          9.0: 2,
#          10.0: 1,
#          11.0: 1,
#          14.0: 1})

# %%
nh_df = pd.DataFrame.from_dict(nh, orient='index').sort_values(by=0)
nh_df.plot(kind='bar', 
           color = 'LightBlue', 
           figsize =(15,8), 
           title = 'Frequency of Number of Bedrooms', 
           legend = False)

# %% [markdown]
# # distribution of review score ratings

# %%
# using Counter to analyze frequency of each listing based on neighborhood
nh = Counter(data_features['review_scores_rating'])
nh
# Out:
# Counter({20.0: 81,
#          30.0: 3,
#          40.0: 81,
#          43.0: 1,
#          45.0: 1,
#          47.0: 3,
#          50.0: 25,
#          51.0: 1,
#          53.0: 5,
#          55.0: 2,
#          56.0: 1,
#          57.0: 5,
#          60.0: 309,
#          62.0: 1,
#          63.0: 4,
#          64.0: 12,
#          65.0: 13,
#          67.0: 40,
#          68.0: 23,
#          69.0: 10,
#          70.0: 122,
#          71.0: 13,
#          72.0: 19,
#          73.0: 102,
#          74.0: 30,
#          75.0: 64,
#          76.0: 51,
#          77.0: 52,
#          78.0: 52,
#          79.0: 42,
#          80.0: 1569,
#          81.0: 63,
#          82.0: 141,
#          83.0: 258,
#          84.0: 271,
#          85.0: 364,
#          86.0: 336,
#          87.0: 707,
#          88.0: 611,
#          89.0: 683,
#          90.0: 1879,
#          91.0: 951,
#          92.0: 1193,
#          93.0: 2141,
#          94.0: 1532,
#          95.0: 1998,
#          96.0: 2161,
#          97.0: 2062,
#          98.0: 2060,
#          99.0: 1074,
#          100.0: 9923})

# %%
nh_df = pd.DataFrame.from_dict(nh, orient='index')
nh_df.plot(kind='bar', 
           color = 'LightBlue', 
           figsize =(15,8), 
           title = 'Distribution of Review ratings', 
           legend = False)

# %%
average_price = sum(data_features.price) / float(len(data_features.price))
average_price
# Out:
# 139.09820485744456

# %% [markdown]
# # average price per city

# %%
# using Counter to analyze frequency of city
nh = Counter(data_features['city'])
nh
# Out:
# Counter({' Brooklyn': 2,
#          ' Crown Heights,NY': 1,
#          ' New York': 1,
#          ' New York ': 1,
#          '11220': 1,
#          '8425 Elmhurst avenue ': 1,
#          'ASTORIA': 3,
#          'ASTORIA/LIC': 1,
#          'Arverne': 6,
#          'Arverne ': 4,
#          'Astoria': 140,
#          'Astoria ': 40,
#          'Astoria - New York': 1,
#          'Astoria New York': 2,
#          'Astoria Queens': 1,
#          'Astoria, New York': 1,
#          'Astoria, New York ': 1,
#          'Astoria, Queens': 4,
#          'Astoria, Queens ': 1,
#          'Astoria,New York ': 1,
#          'Astoria/Queens': 1,
#          'BK': 1,
#          'BROOKLYN': 2,
#          'BROOKLYN ': 1,
#          'Bayonne': 1,
#          'Bayside': 3,
#          'Bayside queens ': 1,
#          'Bayside, Queens': 1,
#          'Bedstuy ': 1,
#          'Bellerose': 1,
#          'Bk': 1,
#          'Bklyn NY': 1,
#          'Briarwood': 2,
#          'Briarwood ': 2,
#          'Bronx': 531,
#          'Bronx ': 34,
#          'Bronx NY ': 1,
#          'Bronx, NY': 2,
#          'Bronx, New York, US': 1,
#          'Bronxville': 1,
#          'Brooklyn': 13517,
#          'Brooklyn\r\nBrooklyn': 1,
#          'Brooklyn ': 543,
#          'Brooklyn  ': 1,
#          'Brooklyn / bushwick': 1,
#          'Brooklyn Heights': 1,
#          'Brooklyn NY ': 2,
#          'Brooklyn city ': 1,
#          'Brooklyn ny ': 1,
#          'Brooklyn,  NY': 1,
#          'Brooklyn,  Ny 11221': 1,
#          'Brooklyn, Bedford Stuyvesant': 1,
#          'Brooklyn, NY': 1,
#          'Brooklyn, New York': 1,
#          'Brooklyn, bedstuy ': 1,
#          'Brooklyn, new York ': 1,
#          'Brooklyn,Park Slope': 1,
#          'Brooklyn/Williamsburg': 1,
#          'Brookyln ': 1,
#          'Brookyn': 1,
#          'Brookyn ': 2,
#          'Bushwick': 4,
#          'Bushwick ': 1,
#          'Bushwick, Brooklyn': 2,
#          'Bushwick/Ridgewood': 1,
#          'Cambria heights ': 1,
#          'Carroll Gardens,Brooklyn, NYC': 1,
#          'Chelsea, New York': 1,
#          'City Island': 2,
#          'Clinton Hill Brooklyn': 8,
#          'College Point': 1,
#          'Corona': 13,
#          'Corona ': 3,
#          'Douglaston': 3,
#          'EAST ELMHURST': 1,
#          'East Elmhurst': 7,
#          'East Elmhurst ': 8,
#          'East Elmhurst (Queens)': 4,
#          'East NY, Brooklyn ': 1,
#          'East Williamsburg': 1,
#          'East Williamsburg ': 1,
#          'East elmhurst': 2,
#          'East elmhurst ': 2,
#          'Elmhurst': 20,
#          'Elmhurst ': 15,
#          'Elmhurst queens 11373': 1,
#          'FLUSHING': 2,
#          'FOREST HILLS': 1,
#          'Far Rockaway': 8,
#          'Far Rockaway ': 2,
#          'Floral Park': 2,
#          'Flush': 1,
#          'Flushing': 57,
#          'Flushing ': 23,
#          'Flushing /Kew Gardens Hills': 1,
#          'Forest Hills': 15,
#          'Forest Hills ': 1,
#          'Forest hills': 3,
#          'Fresh Meadows': 1,
#          'Fresh Meadows ': 2,
#          'Fresh meadows': 1,
#          'Glendale': 2,
#          'Glendale ': 2,
#          'Gravesend Brooklyn ': 1,
#          'Greenpoint ': 2,
#          'Greenpoint, Brooklyn': 2,
#          'Greenwhich Village, New York': 1,
#          'Harlem': 1,
#          "Hell's Kitchen, New York": 1,
#          'Hollis': 2,
#          'JACKSON HEIGHTS': 1,
#          'Jackson  hights ': 1,
#          'Jackson Heights': 12,
#          'Jackson Heights ': 5,
#          'Jackson heights': 1,
#          'Jackson heights ': 3,
#          'Jamaica': 20,
#          'Jamaica ': 14,
#          'Jamaica \r\n': 1,
#          'Kew Gardens': 3,
#          'Kew Gardens ': 1,
#          'Kips Bay': 1,
#          'L.I.C': 1,
#          'LIC': 7,
#          'LONG ISLAND CITY': 3,
#          'Long Island ': 1,
#          'Long Island City': 72,
#          'Long Island City ': 6,
#          'Long Island City, Queens': 1,
#          'Long Island city': 8,
#          'Long Island city ': 3,
#          'Long island city': 3,
#          'Longislandcity ': 1,
#          'MANHATTAN ': 1,
#          'MIDDLE VILLAGE': 1,
#          'Manhattan': 6,
#          'Manhattan ': 1,
#          'Manhattan NY': 1,
#          'Manhattan, New York': 3,
#          'Maspeth': 5,
#          'Maspeth ': 1,
#          'Middle Village': 1,
#          'Mount Vernon': 1,
#          'NUEVA YORK': 1,
#          'NY': 5,
#          'NY ': 3,
#          'NYC': 1,
#          'NYC ': 2,
#          'New York': 14691,
#          'New York ': 52,
#          'New York  ': 1,
#          'New York City': 9,
#          'New York City ': 2,
#          'New York city': 1,
#          'New York, New York, US': 4,
#          'New York, US': 1,
#          'New york': 8,
#          'New york , Ridgewood ': 1,
#          'Newyork': 2,
#          'Nueva York': 2,
#          'Ny': 2,
#          'Oakland Gardens': 3,
#          'Oakland Gardens ': 1,
#          'Park Slope, Brooklyn': 2,
#          'Parkchester ': 1,
#          'Pomona': 1,
#          'Queens': 2541,
#          'Queens ': 16,
#          'Queens Astoria': 1,
#          'Queens Astoria ': 1,
#          'Queens NY': 1,
#          'Queens Village': 3,
#          'Queens Village ': 1,
#          'Queens village': 3,
#          'Queens/Corona/New York': 1,
#          'Red Hook, Brooklyn': 1,
#          'Rego Park': 10,
#          'Rego Park ': 1,
#          'Richmond Hill': 2,
#          'Richmond Hill ': 1,
#          'Richmond Hill, Jamaica, Queens': 1,
#          'Ridgewood': 34,
#          'Ridgewood ': 10,
#          'Ridgwood': 1,
#          'Riverdale ': 2,
#          'Rockaway Beach': 8,
#          'Rockaway Beach ': 2,
#          'Rockaway beach': 2,
#          'Rockaway beach ': 3,
#          'Rosedale': 1,
#          'Rosedale ': 2,
#          'SUNNYSIDE': 1,
#          'Saint Albans': 2,
#          'Saint Albans ': 1,
#          'Saint Albans(Queens)': 1,
#          'South Ozone Park': 2,
#          'South Richmond Hill': 1,
#          'South Richmond hill ': 1,
#          'Springfield Gardens': 2,
#          'Springfield Gardens ': 1,
#          'Springfield gardens': 1,
#          'St. Albans ': 1,
#          'Staten Island': 174,
#          'Staten Island ': 6,
#          'Staten Island New York': 1,
#          'Staten island': 1,
#          'Staten island ': 4,
#          'Statenisland ': 1,
#          'Sunnyside': 12,
#          'Sunnyside ': 5,
#          'Sunnyside Queens': 1,
#          'Wadsworth Terrace, Manhattan, New York': 1,
#          'Whitestone': 1,
#          'Williamsburg': 1,
#          'Williamsburg ': 2,
#          'Williamsburg Brooklyn': 2,
#          'Williamsburg bk': 1,
#          'Williamsburg, Brooklyn': 4,
#          'Williamsburg, Brooklyn ': 2,
#          'Williamsburg,Brooklyn': 1,
#          'Woodhaven': 8,
#          'Woodhaven ': 4,
#          'Woodside': 29,
#          'Woodside ': 10,
#          'Woodside, Queens ': 1,
#          'Yonkers': 2,
#          'astoria': 4,
#          'bayside': 1,
#          'bronx': 7,
#          'brooklyn': 24,
#          'brooklyn ': 9,
#          'brooklyn, NY': 1,
#          'elmhurst Queens': 1,
#          'flushing': 13,
#          'flushing ': 1,
#          'forest hills': 1,
#          'forest hills/corona': 1,
#          'hollis': 1,
#          'jackson heights': 1,
#          'long island city': 3,
#          'new York ': 1,
#          'new york': 7,
#          'nyc': 1,
#          'nyc ': 1,
#          'ozone park queens ': 1,
#          'queens': 4,
#          'queens ': 1,
#          'richmond hill': 1,
#          'ridgewood': 1,
#          'sunnyside': 1,
#          'west new york ': 1,
#          'woodside': 2,
#          '\xe5\xb8\x83\xe9\xb2\x81\xe5\x85\x8b\xe6\x9e\x97': 1,
#          '\xe6\xb3\x95\xe6\x8b\x89\xe7\x9b\x9b': 1,
#          '\xe7\xba\xbd\xe7\xba\xa6': 1,
#          '\xe7\xba\xbd\xe7\xba\xa6\xe5\xb8\x82': 7,
#          '\xe7\xba\xbd\xe7\xba\xa6\xe6\xb3\x95\xe6\x8b\x89\xe7\x9b\x9b': 1})

# %%
# extracting the names
city_names = list(nh.keys())

# 2 column table of neighborhood names and prices
nh_prices = data_features[['neighbourhood', 'price']]
nh_prices.columns = ['city', 'price']

# we pick out the rows which have neighborhood names and city_names in common
nh_prices = nh_prices[nh_prices['city'].isin(city_names)]

# group by neighbourhood and then aggreate the prices based on mean
nh_prices_group = nh_prices.groupby('city')
nh_prices = nh_prices_group['price'].agg(np.mean)

# turn dictionary's keys and values into a table for easy read
nh_prices = nh_prices.reset_index()
nh_prices
# Out:
#                 city       price
# 0            Astoria  112.019095
# 1            Bayside   96.196078
# 2           Brooklyn   94.235294
# 3   Brooklyn Heights  183.245283
# 4           Bushwick   84.605505
# 5        City Island   89.000000
# 6      College Point  106.750000
# 7             Corona   60.763889
# 8      East Elmhurst   67.829268
# 9           Elmhurst   74.569343
# 10          Flushing   97.702703
# 11      Forest Hills  110.092593
# 12     Fresh Meadows  136.250000
# 13          Glendale   70.692308
# 14            Harlem  114.750000
# 15   Jackson Heights   76.305732
# 16           Jamaica   77.689231
# 17          Kips Bay  208.795620
# 18  Long Island City  122.532374
# 19         Manhattan  237.214286
# 20           Maspeth   82.977778
# 21    Middle Village  108.368421
# 22            Queens   62.500000
# 23         Rego Park   75.907692
# 24     Richmond Hill   77.662338
# 25         Ridgewood   77.225694
# 26  South Ozone Park   81.000000
# 27         Sunnyside   89.098425
# 28        Whitestone  126.600000
# 29      Williamsburg  134.134733
# 30         Woodhaven   50.342105
# 31          Woodside   78.877778

# %%
p = nh_prices.sort_values(by = 'price')
p.plot(x = "city",
       y = "price",
       kind='bar', 
       color = 'LightBlue', 
       figsize =(15,8), 
       title = 'Price per City', 
       legend = False)

# %%
prop_room = data_features[['property_type', 'room_type', 'price']]

# first ten of the table
prop_room[0:10]
# Out:
#    property_type        room_type  price
# 0      Apartment     Private room   59.0
# 1      Apartment     Private room   39.0
# 3      Apartment     Private room   70.0
# 5          Other  Entire home/apt   89.0
# 6      Apartment  Entire home/apt  150.0
# 7      Apartment  Entire home/apt  150.0
# 9      Apartment  Entire home/apt  253.0
# 10     Apartment  Entire home/apt  129.0
# 11     Apartment     Private room   79.0
# 12     Apartment     Private room   79.0

# %% [markdown]
# # Grouping by property and room type, and then aggregating them using mean of the price

# %%
prop_room_group = prop_room.groupby(['property_type', 'room_type']).mean()

# resetting the index in order to turn the lists into a readable table
p = prop_room_group.reset_index()

# pivoting the table based on the 3 factors, in order.
p = p.pivot('property_type', 'room_type', 'price')

# replacing the NaN values with 0
p.fillna(0.00, inplace=True)

p
# Out:
# room_type               Entire home/apt  Private room  Shared room
# property_type
# Aparthotel                     0.000000    131.500000     0.000000
# Apartment                    192.933338     81.011906    60.241791
# Bed and breakfast            286.545455     89.810811    35.000000
# Boat                          80.000000    600.000000     0.000000
# Boutique hotel               185.000000    164.962963     0.000000
# Bungalow                     176.666667     77.285714     0.000000
# Cabin                          0.000000     80.000000     0.000000
# Camper/RV                    210.000000     50.000000     0.000000
# Casa particular (Cuba)         0.000000     44.000000     0.000000
# Castle                       192.000000      0.000000     0.000000
# Cave                         120.000000     35.000000     0.000000
# Chalet                         0.000000    101.000000     0.000000
# Condominium                  313.777328     91.979866    54.000000
# Cottage                      216.000000      0.000000     0.000000
# Dorm                          80.000000     65.615385    32.666667
# Earth house                  144.500000    115.000000     0.000000
# Guest suite                  130.886792     87.846154    96.000000
# Guesthouse                   148.000000     72.350000     0.000000
# Hostel                       320.000000     72.692308    28.800000
# Hotel                       1100.000000    213.600000     0.000000
# House                        251.427813     66.055821    54.000000
# Hut                            0.000000     79.000000    25.000000
# In-law                       112.600000     50.000000    30.000000
# Island                        70.000000      0.000000     0.000000
# Loft                         305.944844    117.080332    71.428571
# Other                        160.712121    102.402439    56.222222
# Serviced apartment           346.152778     92.828571    36.500000
# Tent                           0.000000    150.000000     0.000000
# Timeshare                    393.785714    171.800000     0.000000
# Tiny house                     0.000000     40.000000     0.000000
# Townhouse                    285.026699     74.644068    34.388889
# Treehouse                      0.000000     56.000000     0.000000
# Vacation home                326.500000     98.333333     0.000000
# Villa                        243.750000     71.000000     0.000000
# Yurt                          95.000000      0.000000     0.000000
